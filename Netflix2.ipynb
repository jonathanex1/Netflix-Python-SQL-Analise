# %% [markdown]
# ![netflix_img2.png](attachment:netflix_img2.png)

# %% [markdown]
# # Jupyter 2

# %%
import pandas as pd
import numpy as np
import tratamento_ausentes as ta

# %%
# Lendo o dataframe finalizado no primeiro Jupyter do projeto
df = pd.read_csv('netflix_df.csv', sep = ',')

# %%
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
#
# ...

# %% [markdown]
# ## Verificando os Valores Únicos das colunas

# %%
df['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df.loc[df['rating']=='74 min']
# Out:
#        type            title    director        cast        country  \
# 5541  Movie  Louis C.K. 2017  Louis C.K.  Louis C.K.  United States
#
#       release_year  rating duration listed_in  \
# 5541          2017  74 min      NaN    Movies
#
#                                             description month_added  \
# 5541  Louis C.K. muses on religion, eternal love, gi...       April
#
#       day_added  year_added
# 5541        4.0      2017.0

# %% [markdown]
# <blockquote> Classificação Indicativa </blockquote>

# %%
# PG-13 = Parents Strongly Cautioned, não recomendado para menores de 13 anos, alerta para os pais.
# TV-MA = não recomendado para menores de 17 anos
# PG = Parental Guidance Suggested, Programa pode não ser adequado para crianças menores sem a orientação dos pais
# TV-14 = Não recomendado para menores de 14 anos
# TV-PG = Classificação destinada com a orientação parental
# TV-Y = Conteúdo infantil
# TV-Y7 = Não recomendado para menores de 7 anos
# TV-G = Recomendado para todos os públicos
# G = General Audiences, All Ages Admitted, conteúdo para todas as idades
# NC-17 = No One 17 and Under Admitted, Conteúdo para maiores de 18 anos
# NR = Not Rated, conteúdo não validado
# TV-Y7-FV = Não recomendado para menores de 7 anos com violência fantasiosa
# UR = Menores de 17 anos necessitam acompanhamento dos pais ou responsáveis

# %% [markdown]
# ## Removendo dados de duração da coluna rating

# %%
df.loc[df['rating']=='74 min']
# Out:
#        type            title    director        cast        country  \
# 5541  Movie  Louis C.K. 2017  Louis C.K.  Louis C.K.  United States
#
#       release_year  rating duration listed_in  \
# 5541          2017  74 min      NaN    Movies
#
#                                             description month_added  \
# 5541  Louis C.K. muses on religion, eternal love, gi...       April
#
#       day_added  year_added
# 5541        4.0      2017.0

# %%
df.loc[df['rating']=='84 min']
# Out:
#        type                  title    director        cast        country  \
# 5794  Movie  Louis C.K.: Hilarious  Louis C.K.  Louis C.K.  United States
#
#       release_year  rating duration listed_in  \
# 5794          2010  84 min      NaN    Movies
#
#                                             description month_added  \
# 5794  Emmy-winning comedy writer Louis C.K. brings h...   September
#
#       day_added  year_added
# 5794       16.0      2016.0

# %%
df.loc[df['rating']=='66 min']
# Out:
#        type                                 title    director        cast  \
# 5813  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#             country  release_year  rating duration listed_in  \
# 5813  United States          2015  66 min      NaN    Movies
#
#                                             description month_added  \
# 5813  The comic puts his trademark hilarious/thought...      August
#
#       day_added  year_added
# 5813       15.0      2016.0

# %%
# Substituindo valores 74, 84 e 66 min por 'NA'

df['rating'] = df['rating'].replace({'74 min': 'NA','84 min': 'NA', '66 min': 'NA' })

# %%
# Verificando os dados

df.loc[df['director'] == 'Louis C.K.']
# Out:
#        type                                 title    director        cast  \
# 5541  Movie                       Louis C.K. 2017  Louis C.K.  Louis C.K.
# 5794  Movie                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
# 5813  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#             country  release_year rating duration listed_in  \
# 5541  United States          2017     NA      NaN    Movies
# 5794  United States          2010     NA      NaN    Movies
# 5813  United States          2015     NA      NaN    Movies
#
#                                             description month_added  \
# 5541  Louis C.K. muses on religion, eternal love, gi...       April
# 5794  Emmy-winning comedy writer Louis C.K. brings h...   September
# 5813  The comic puts his trademark hilarious/thought...      August
#
#       day_added  year_added
# 5541        4.0      2017.0
# 5794       16.0      2016.0
# 5813       15.0      2016.0

# %%
# Inputando dados que estavam na coluna rating para a coluna duration

df = df.replace({'duration': {'Não Informado': ['74 min','84 min','66 min']}})

# %% [markdown]
# ## Dividindo o Dataset entre Movie e TV Shows

# %%
new_df1 = pd.DataFrame(df)

# %%
new_df1.head(2)
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description month_added  day_added  \
# 0  As her father nears the end of his life, filmm...   September       25.0
# 1  After crossing paths at a party, a Cape Town t...   September       24.0
#
#    year_added
# 0      2021.0
# 1      2021.0

# %%
new_df1 = new_df1.loc[(new_df1['type'] == 'Movie')]

# %%
new_df1.type.value_counts()
# Out:
# Movie    6131
# Name: type, dtype: int64

# %%
new_df2 = pd.DataFrame(df)

# %%
new_df2.head(2)
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description month_added  day_added  \
# 0  As her father nears the end of his life, filmm...   September       25.0
# 1  After crossing paths at a party, a Cape Town t...   September       24.0
#
#    year_added
# 0      2021.0
# 1      2021.0

# %%
new_df2 = new_df2.loc[(new_df2['type'] == 'TV Show')]

# %%
new_df2.type.value_counts()
# Out:
# TV Show    2676
# Name: type, dtype: int64

# %%
new_df2.head()
# Out:
#       type                  title         director  \
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
# 5  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
#
# ...

# %%
new_df1.head()
# Out:
#      type                             title                       director  \
# 0   Movie              Dick Johnson Is Dead                Kirsten Johnson
# 6   Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7   Movie                           Sankofa                   Haile Gerima
# 9   Movie                      The Starling                 Theodore Melfi
# 12  Movie                      Je Suis Karl            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country  release_year rating  \
# 0                                       United States          2020  PG-13
# ...

# %% [markdown]
# ## Modificando a coluna duration

# %% [markdown]
# #### Transformando o dataset new_df1  (Movies)

# %%
new_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6131 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          6131 non-null   object
#  1   title         6131 non-null   object
#  2   director      5943 non-null   object
#  3   cast          5656 non-null   object
#  4   country       5691 non-null   object
#  5   release_year  6131 non-null   int64
#  6   rating        6129 non-null   object
#  7   duration      6128 non-null   object
#  8   listed_in     6131 non-null   object
#  9   description   6131 non-null   object
#  10  month_added   6131 non-null   object
#  11  day_added     6131 non-null   float64
#  12  year_added    6131 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 670.6+ KB

# %%
# Removendo caracteres e deixando apenas números

new_df1['duration'] = new_df1['duration'].str.replace(' min','')

# %%
new_df1.head(3)
# Out:
#     type                             title                       director  \
# 0  Movie              Dick Johnson Is Dead                Kirsten Johnson
# 6  Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7  Movie                           Sankofa                   Haile Gerima
#
#                                                 cast  \
# 0                                                NaN
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country  release_year rating  \
# 0                                      United States          2020  PG-13
# 6                                                NaN          2021     PG
# 7  United States, Ghana, Burkina Faso, United Kin...          1993  TV-MA
#
#   duration                                         listed_in  \
# 0       90                                     Documentaries
# ...

# %%
new_df1.duration.unique()
# Out:
# array(['90', '91', '125', '104', '127', '67', '94', '161', '61', '166',
#        '147', '103', '97', '106', '111', '110', '105', '96', '124', '116',
#        '98', '23', '115', '122', '99', '88', '100', '102', '93', '95',
#        '85', '83', '113', '13', '182', '48', '145', '87', '92', '80',
#        '117', '128', '119', '143', '114', '118', '108', '63', '121',
#        '142', '154', '120', '82', '109', '101', '86', '229', '76', '89',
#        '156', '112', '107', '129', '135', '136', '165', '150', '133',
#        '70', '84', '140', '78', '64', '59', '139', '69', '148', '189',
#        '141', '130', '138', '81', '132', '123', '65', '68', '66', '62',
#        '74', '131', '39', '46', '38', '126', '155', '159', '137', '12',
#        '273', '36', '34', '77', '60', '49', '58', '72', '204', '212',
#        '25', '73', '29', '47', '32', '35', '71', '149', '33', '15', '54',
#        '224', '162', '37', '75', '79', '55', '158', '164', '173', '181',
# ...

# %% [markdown]
# #### Transformando o dataset new_df2 (TV Show)

# %%
new_df2.duration.value_counts()
# Out:
# 1 Season      1793
# 2 Seasons      425
# 3 Seasons      199
# 4 Seasons       95
# 5 Seasons       65
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       7
# 13 Seasons       3
# 15 Seasons       2
# 12 Seasons       2
# 11 Seasons       2
# 17 Seasons       1
# Name: duration, dtype: int64

# %%
new_df2['qtd_seasons'] = new_df2['duration'].str.replace(" Seasons", "")

# %%
new_df2['qtd_seasons'] = new_df2['qtd_seasons'].str.replace(" Season", "")

# %%
new_df2.head(5)
# Out:
#       type                  title         director  \
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
# 5  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
#
# ...

# %%
new_df2['qtd_seasons'].value_counts()
# Out:
# 1     1793
# 2      425
# 3      199
# 4       95
# 5       65
# 6       33
# 7       23
# 8       17
# 9        9
# 10       7
# 13       3
# 15       2
# 12       2
# 11       2
# 17       1
# Name: qtd_seasons, dtype: int64

# %%
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
#
# ...

# %% [markdown]
# ## Unindo os datasets modificados com o dataset original

# %%
# Criando uma cópia do dataframe original para testar o merge
df2 = df.copy()

# %%
df2.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
#
# ...

# %%
df2['duration'] = new_df1['duration']

# %%
df2.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating duration  \
# 0          2020  PG-13       90
# 1          2021  TV-MA      NaN
# 2          2021  TV-MA      NaN
# 3          2021  TV-MA      NaN
# 4          2021  TV-MA      NaN
#
# ...

# %%
df2['qtd_seasons'] = 0

# %%
df2.head(1)
# Out:
#     type                 title         director cast        country  \
# 0  Movie  Dick Johnson Is Dead  Kirsten Johnson  NaN  United States
#
#    release_year rating duration      listed_in  \
# 0          2020  PG-13       90  Documentaries
#
#                                          description month_added  day_added  \
# 0  As her father nears the end of his life, filmm...   September       25.0
#
#    year_added  qtd_seasons
# 0      2021.0            0

# %%
df2['qtd_seasons'] = new_df2['qtd_seasons']

# %%
df2.head(10)
# Out:
#       type                             title                       director  \
# 0    Movie              Dick Johnson Is Dead                Kirsten Johnson
# 1  TV Show                     Blood & Water                            NaN
# 2  TV Show                         Ganglands                Julien Leclercq
# 3  TV Show             Jailbirds New Orleans                            NaN
# 4  TV Show                      Kota Factory                            NaN
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
# 8  TV Show     The Great British Baking Show                Andy Devonshire
# 9    Movie                      The Starling                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# ...

# %%
# O resultado foi como esperado, agora o procedimento será
# remover os valores ausentes das colunas e transformá-los

# %%
df = df2

# %%
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating duration  \
# 0          2020  PG-13       90
# 1          2021  TV-MA      NaN
# 2          2021  TV-MA      NaN
# 3          2021  TV-MA      NaN
# 4          2021  TV-MA      NaN
#
# ...

# %%
ta.func_calc_percentual_valores_ausentes_coluna(df)
# Out:
# O dataset tem 14 colunas.
# Encontrado: 9 colunas que têm valores ausentes.
#              Valores Ausentes  % de Valores Ausentes    Dtype
# qtd_seasons              6131                  69.62   object
# duration                 2679                  30.42   object
# director                 2634                  29.91   object
# country                   831                   9.44   object
# cast                      825                   9.37   object
# month_added                10                   0.11   object
# day_added                  10                   0.11  float64
# year_added                 10                   0.11  float64
# rating                      4                   0.05   object

# %%
ta.fix_missing_value(df,'qtd_seasons', 0)
# Out:
# 6131 valores ausentes na coluna qtd_seasons foram substituídos por 0.
# 0       0
# 1       2
# 2       1
# 3       1
# 4       2
#        ..
# 8802    0
# 8803    2
# 8804    0
# 8805    0
# 8806    0
# Name: qtd_seasons, Length: 8807, dtype: object

# %%
ta.fix_missing_value(df,'duration', 0)
# Out:
# 2679 valores ausentes na coluna duration foram substituídos por 0.
# 0        90
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 8802    158
# 8803      0
# 8804     88
# 8805     88
# 8806    111
# Name: duration, Length: 8807, dtype: object

# %%
ta.fix_missing_value(df,'director', 'NA')
# Out:
# 2634 valores ausentes na coluna director foram substituídos por NA.
# 0       Kirsten Johnson
# 1                    NA
# 2       Julien Leclercq
# 3                    NA
# 4                    NA
#              ...
# 8802      David Fincher
# 8803                 NA
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
ta.fix_missing_value(df,'country', 'NA')
# Out:
# 831 valores ausentes na coluna country foram substituídos por NA.
# 0       United States
# 1        South Africa
# 2                  NA
# 3                  NA
# 4               India
#             ...
# 8802    United States
# 8803               NA
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %%
ta.fix_missing_value(df,'cast', 'NA')
# Out:
# 825 valores ausentes na coluna cast foram substituídos por NA.
# 0                                                      NA
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                      NA
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                   NA
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %%
ta.func_calc_percentual_valores_ausentes_coluna(df)
# Out:
# O dataset tem 14 colunas.
# Encontrado: 4 colunas que têm valores ausentes.
#              Valores Ausentes  % de Valores Ausentes    Dtype
# month_added                10                   0.11   object
# day_added                  10                   0.11  float64
# year_added                 10                   0.11  float64
# rating                      4                   0.05   object

# %%
df.loc[(df['month_added'].isnull())]
# Out:
#          type                                        title director  \
# 6066  TV Show  A Young Doctor's Notebook and Other Stories       NA
# 6174  TV Show              Anthony Bourdain: Parts Unknown       NA
# 6795  TV Show                                      Frasier       NA
# 6806  TV Show                                      Friends       NA
# 6901  TV Show                              Gunslinger Girl       NA
# 7196  TV Show                                     Kikoriki       NA
# 7254  TV Show                          La Familia P. Luche       NA
# 7406  TV Show                                        Maron       NA
# 7847  TV Show                                 Red vs. Blue       NA
# 8182  TV Show                 The Adventures of Figaro Pho       NA
#
#                                                    cast         country  \
# 6066  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6174                                   Anthony Bourdain   United States
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   release_year  8807 non-null   int64
#  6   rating        8803 non-null   object
#  7   duration      8807 non-null   object
#  8   listed_in     8807 non-null   object
#  9   description   8807 non-null   object
#  10  month_added   8797 non-null   object
#  11  day_added     8797 non-null   float64
#  12  year_added    8797 non-null   float64
#  13  qtd_seasons   8807 non-null   object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 963.4+ KB

# %%
ta.fix_missing_value(df,'month_added', 'NA')
# Out:
# 10 valores ausentes na coluna month_added foram substituídos por NA.
# 0       September
# 1       September
# 2       September
# 3       September
# 4       September
#           ...
# 8802     November
# 8803         July
# 8804     November
# 8805      January
# 8806        March
# Name: month_added, Length: 8807, dtype: object

# %%
ta.fix_missing_value(df,'day_added', '99.0')
# Out:
# 10 valores ausentes na coluna day_added foram substituídos por 99.0.
# 0       25.0
# 1       24.0
# 2       24.0
# 3       24.0
# 4       24.0
#         ...
# 8802    20.0
# 8803     1.0
# 8804     1.0
# 8805    11.0
# 8806     2.0
# Name: day_added, Length: 8807, dtype: object

# %%
ta.fix_missing_value(df,'year_added', '9999.0')
# Out:
# 10 valores ausentes na coluna year_added foram substituídos por 9999.0.
# 0       2021.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2019.0
# 8803    2019.0
# 8804    2019.0
# 8805    2020.0
# 8806    2019.0
# Name: year_added, Length: 8807, dtype: object

# %%
ta.func_calc_percentual_valores_ausentes_coluna(df)
# Out:
# O dataset tem 14 colunas.
# Encontrado: 1 colunas que têm valores ausentes.
#         Valores Ausentes  % de Valores Ausentes   Dtype
# rating                 4                   0.05  object

# %%
df.loc[(df['rating'].isnull())]
# Out:
#          type                                              title  \
# 5989    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827  TV Show                  Gargantia on the Verdurous Planet
# 7312  TV Show                                       Little Lunch
# 7537    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989               NA                        Oprah Winfrey, Ava DuVernay
# 6827               NA  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312               NA  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#         country  release_year rating duration  \
# 5989         NA          2017    NaN       37
# 6827      Japan          2013    NaN        0
# 7312  Australia          2015    NaN        0
# 7537      Italy          2015    NaN      115
#
# ...

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NA', 'NR', nan, 'TV-Y7-FV', 'UR'],
#       dtype=object)

# %%
ta.fix_missing_value(df,'rating', 'NA')
# Out:
# 4 valores ausentes na coluna rating foram substituídos por NA.
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
ta.func_calc_percentual_valores_ausentes_coluna(df)
# Out:
# O dataset tem 14 colunas.
# Encontrado: 0 colunas que têm valores ausentes.

# %%
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water               NA
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans               NA
# 4  TV Show           Kota Factory               NA
#
#                                                 cast        country  \
# 0                                                 NA  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...             NA
# 3                                                 NA             NA
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating duration  \
# 0          2020  PG-13       90
# 1          2021  TV-MA        0
# 2          2021  TV-MA        0
# 3          2021  TV-MA        0
# 4          2021  TV-MA        0
#
# ...

# %%
# Salvando o dataframe para continuar o projeto posteriormente.
df.to_csv('netflix_dfv2.csv', index = False)
